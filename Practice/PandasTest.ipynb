# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')
print("First 5 rows:")
print(diamonds.head())
# Out:
# First 5 rows:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
type(diamonds)
# Out:
# pandas.core.frame.DataFrame

# %%
diamonds.count()
# Out:
# carat      53940
# cut        53940
# color      53940
# clarity    53940
# depth      53940
# table      53940
# price      53940
# x          53940
# y          53940
# z          53940
# dtype: int64

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds.tail(4)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
diamonds.head(50).to_csv('top50sample.csv',sep="|",index=False)

# %%
df = pd.read_csv('top50sample.csv',sep="|",header=None,names=['col1','col2','col3','col4','col5'])
df
# Out:
#                                       col1   col2  col3  col4  col5
# carat cut       color clarity depth  table  price     x     y     z
# 0.23  Ideal     E     SI2     61.5    55.0    326  3.95  3.98  2.43
# 0.21  Premium   E     SI1     59.8    61.0    326  3.89  3.84  2.31
# 0.23  Good      E     VS1     56.9    65.0    327  4.05  4.07  2.31
# 0.29  Premium   I     VS2     62.4    58.0    334   4.2  4.23  2.63
# ...                                    ...    ...   ...   ...   ...
#                 F     SI1     62.4    58.0    403  4.24  4.26  2.65
# 0.32  Very Good H     SI2     61.8    55.0    403  4.35  4.42  2.71
#       Good      H     SI2     63.8    56.0    403  4.36  4.38  2.79
# 0.25  Very Good E     VS2     63.3    60.0    404   4.0  4.03  2.54
# 0.29  Very Good H     SI2     60.7    60.0    404  4.33  4.37  2.64
#
# [51 rows x 5 columns]

# %%
df = pd.read_csv('top50sample.csv',sep="|",header=None,names=['carat', 'cut','color', 'clarity' ,'depth' ,'table', 'price' ,'x' , 'y' ,'z']
                 ,skiprows=[0,10] #skipping rows 0th and 10th
                ,na_values=[0.23]) # will consider 0.23 value as NaN
df.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0    NaN      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    NaN       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
df.describe()
# Out:
#            carat      depth      table       price          x          y  \
# count  34.000000  49.000000  49.000000   49.000000  49.000000  49.000000
# mean    0.283824  61.679592  57.734694  368.285714   4.129796   4.152653
# std     0.037660   1.846503   2.604287   29.811910   0.202582   0.216485
# min     0.200000  56.900000  54.000000  326.000000   3.790000   3.750000
# 25%     0.260000  60.500000  56.000000  344.000000   3.960000   3.980000
# 50%     0.300000  61.900000  57.000000  354.000000   4.070000   4.110000
# 75%     0.310000  63.100000  59.000000  402.000000   4.310000   4.340000
# max     0.330000  65.200000  65.000000  404.000000   4.490000   4.550000
#
#                z
# count  49.000000
# mean    2.553878
# std     0.149538
# min     2.270000
# 25%     2.420000
# 50%     2.530000
# 75%     2.700000
# max     2.790000

# %%
df.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0    NaN      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    NaN       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73

# %%
df.head(10).describe()
# min 0th percentile 
# max 100th percentile
# Out:
#           carat    depth      table      price          x          y  \
# count  8.000000  10.0000  10.000000   10.00000  10.000000  10.000000
# mean   0.258750  62.0000  58.200000  333.30000   4.051000   4.058000
# std    0.037583   2.2925   3.259175    4.98999   0.162306   0.186655
# min    0.210000  56.9000  55.000000  326.00000   3.870000   3.780000
# 25%    0.235000  61.6000  55.500000  328.75000   3.942500   3.965000
# 50%    0.250000  62.3500  57.500000  335.50000   4.000000   4.025000
# 75%    0.292500  63.1750  60.250000  336.75000   4.167500   4.200000
# max    0.310000  65.1000  65.000000  339.00000   4.340000   4.350000
#
#                z
# count  10.000000
# mean    2.513000
# std     0.152756
# min     2.310000
# 25%     2.440000
# 50%     2.485000
# 75%     2.605000
# max     2.750000

# %%
print((0.22+0.24)/2)
# Out:
# 0.22999999999999998

# %%
print(8*0.25)
# Out:
# 2.0

# %%
diamonds.head(50).to_csv('custom.csv',sep="#",index=False,header=False,columns=['carat','table','price'])

# %%
df1 = pd.read_csv('custom.csv',sep="#",header=None,names=['carat','table','price'])
df1.tail()
# Out:
#     carat  table  price
# 45   0.29   58.0    403
# 46   0.32   55.0    403
# 47   0.32   56.0    403
# 48   0.25   60.0    404
# 49   0.29   60.0    404

# %%
df1.columns
# Out:
# Index(['carat', 'table', 'price'], dtype='object')

# %%
df1['carat'].head(2)
# Out:
# 0    0.23
# 1    0.21
# Name: carat, dtype: float64

# %%
type(df1['carat']) # Equivalent to list
# Out:
# pandas.core.series.Series

# %%
df1['carat'][0]
# Out:
# 0.23

# %%
type(df1[['carat']])
# Out:
# pandas.core.frame.DataFrame

# %%
df1[['carat']].head(2)
# Out:
#    carat
# 0   0.23
# 1   0.21

# %%
df1[['carat','table']].head(2)
# Out:
#    carat  table
# 0   0.23   55.0
# 1   0.21   61.0

# %%
edf = pd.read_excel('employee.xlsx',sheet_name='Sheet2')
edf
# Out:
#     emp_id first_name    last_name  hire_date
# 0      120    Matthew        Weiss 2004-07-18
# 1      121       Adam        Fripp 2005-04-10
# 2      122      Payam     Kaufling 2003-05-01
# 3      123     Shanta      Vollman 2005-10-10
# 4      124      Kevin      Mourgos 2007-11-16
# 5      125      Julia        Nayer 2005-07-16
# 6      126      Irene  Mikkilineni 2006-09-28
# 7      127      James       Landry 2007-01-14
# 8      128     Steven       Markle 2008-03-08
# 9      129      Laura       Bissot 2005-08-20
# 10     130      Mozhe     Atkinson 2005-10-30
# 11     131      James       Marlow 2005-02-16
# 12     132         TJ        Olson 2007-04-10
# 13     133      Jason       Mallin 2004-06-14
# 14     134    Michael       Rogers 2006-08-26
# 15     135         Ki          Gee 2007-12-12
# 16     136      Hazel   Philtanker 2008-02-06
# 17     137     Renske       Ladwig 2003-07-14
# 18     138    Stephen       Stiles 2005-10-26

# %%
hdf = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
hdf
# Out:
# [       Season   Age                                   Team  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
# ...

# %%
type(hdf)
# Out:
# list

# %%
type(hdf[0])
# Out:
# pandas.core.frame.DataFrame

# %%
hdf[0].head()
# Out:
#     Season   Age                                   Team  \
# 0  2008-09  19.0  Did Not Play (other pro league—Spain)
# 1  2009-10  20.0                                    OKC
# 2  2010-11  21.0                                    OKC
# 3  2011-12  22.0                                    OKC
# 4  2012-13  23.0                                    OKC
#
#                                       Lg  \
# 0  Did Not Play (other pro league—Spain)
# 1                                    NBA
# 2                                    NBA
# 3                                    NBA
# 4                                    NBA
#
#                                      Pos  \
# 0  Did Not Play (other pro league—Spain)
# 1                                     PF
# 2                                     PF
# 3                                     PF
# 4                                     PF
#
#                                        G  \
# 0  Did Not Play (other pro league—Spain)
# ...

# %%
hdf[0].to_excel('basketball_sampledata.xlsx',index=False)

# %%
pd.read_excel('basketball_sampledata.xlsx').head()
# Out:
#     Season   Age                                   Team  \
# 0  2008-09  19.0  Did Not Play (other pro league—Spain)
# 1  2009-10  20.0                                    OKC
# 2  2010-11  21.0                                    OKC
# 3  2011-12  22.0                                    OKC
# 4  2012-13  23.0                                    OKC
#
#                                       Lg  \
# 0  Did Not Play (other pro league—Spain)
# 1                                    NBA
# 2                                    NBA
# 3                                    NBA
# 4                                    NBA
#
#                                      Pos  \
# 0  Did Not Play (other pro league—Spain)
# 1                                     PF
# 2                                     PF
# 3                                     PF
# 4                                     PF
#
#                                        G  \
# 0  Did Not Play (other pro league—Spain)
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = """
{
 "name" : "Atul",
 "phone_no" : 970134354,
 "tech_stack" : ["HTML","Python","JS"]
}
"""

# %%
s
# Out:
# '\n{\n "name" : "Atul",\n "phone_no" : 970134354,\n "tech_stack" : ["HTML","Python","JS"]\n}\n'

# %%
import json

# %%
jdata = json.loads(s)

# %%
pd.DataFrame(jdata)
# Out:
#    name   phone_no tech_stack
# 0  Atul  970134354       HTML
# 1  Atul  970134354     Python
# 2  Atul  970134354         JS

# %%
pd.DataFrame(jdata,columns=['tech_stack'])
# Out:
#   tech_stack
# 0       HTML
# 1     Python
# 2         JS

# %%
import requests

# %%
raw = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
jdata = raw.json()
jdata
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41825/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/41825',
#   'id': 912116016,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYyMzEwNDI2',
#   'number': 41825,
#   'title': 'REF: share wrapping in MultiIndex setops',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
# ...

# %%
for i in range(len(jdata)):
    print(jdata[i]['title'])
# Out:
# REF: share wrapping in MultiIndex setops
# REF: de-duplicate Index._intersection + MultiIndex._intersection
# BUG: MultiIndex.unique incorrect when NA value is present
# DOC: Whatsnew1.3 grammar
# BUG: wrong exception when slicing on TimedeltaIndex
# BUG: read_csv does not read double double quotes in pipe delimited txt file
# DOC/BLD: update README.md, list setuptools as dependency
# BUG: pd.util.hash_array fails on DatetimeIndex with tz specified
# DEPS: clarifying setuptools's status as a dependency
# Axis behaviour not consistent for df.interpolate for pad with `limit_area` passed.
# TYP: Numpy compatibility of definition of "array like"
# BUG:
# BUG: combine_first fails when one series is timezone-aware and the other is emtpy.
# BUG: undocumented astype("category").astype(str) type inconsistency between pandas 1.1 & 1.2
# BUG: `round()` for 5e5 ms should be `ceil()`
# BUG: Broken bool supports in pandas' quantile by NumPy's percentile behaviour change
# ...

# %%
pd.DataFrame(jdata,columns=['title','url','user']).head()
# Out:
#                                                title  \
# 0           REF: share wrapping in MultiIndex setops
# 1  REF: de-duplicate Index._intersection + MultiI...
# 2  BUG: MultiIndex.unique incorrect when NA value...
# 3                           DOC: Whatsnew1.3 grammar
# 4  BUG: wrong exception when slicing on Timedelta...
#
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 user
# 0  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 1  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 2  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 3  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 4  {'login': 'jbrockmendel', 'id': 8078968, 'node...

# %%
dictArr = []
for i in range(len(jdata)):
    js = jdata[i]['user']
    dictArr.append(js)
    
#print(len(dictArr))
#print(dictArr)
df = pd.DataFrame(dictArr)
df.head()
# Out:
#           login        id               node_id  \
# 0  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 1  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3    rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 4  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/807896...
# 1  https://avatars.githubusercontent.com/u/807896...
# 2  https://avatars.githubusercontent.com/u/807896...
# 3  https://avatars.githubusercontent.com/u/455624...
# 4  https://avatars.githubusercontent.com/u/807896...
#
#                                          url                         html_url  \
# 0  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
# 1  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
# 2  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
# ...

# %%
filedf = pd.read_csv("top50sample.csv")

# %% [markdown]
# # serde -> serialization and deserialization

# %%
# serialization of data with the help of pickle (binary)file format
filedf.to_pickle("top50sample_pickle") # convert data object into bycode

# %%
# to deserialize 
pd.read_pickle("top50sample_pickle").head()
# Out:
#    carat|cut|color|clarity|depth|table|price|x|y|z
# 0    0.23|Ideal|E|SI2|61.5|55.0|326|3.95|3.98|2.43
# 1  0.21|Premium|E|SI1|59.8|61.0|326|3.89|3.84|2.31
# 2     0.23|Good|E|VS1|56.9|65.0|327|4.05|4.07|2.31
# 3   0.29|Premium|I|VS2|62.4|58.0|334|4.2|4.23|2.63
# 4     0.31|Good|J|SI2|63.3|58.0|335|4.34|4.35|2.75

# %%
h5data = pd.HDFStore("test.h5")

# %%
h5data['obj1'] = filedf

# %%
h5data['obj1'].head()
# Out:
#    carat|cut|color|clarity|depth|table|price|x|y|z
# 0    0.23|Ideal|E|SI2|61.5|55.0|326|3.95|3.98|2.43
# 1  0.21|Premium|E|SI1|59.8|61.0|326|3.89|3.84|2.31
# 2     0.23|Good|E|VS1|56.9|65.0|327|4.05|4.07|2.31
# 3   0.29|Premium|I|VS2|62.4|58.0|334|4.2|4.23|2.63
# 4     0.31|Good|J|SI2|63.3|58.0|335|4.34|4.35|2.75

# %%
type(h5data)
# Out:
# pandas.io.pytables.HDFStore

# %%
h5data.put("obj2",filedf , format="table")

# %%
h5data.select("obj2",where=['index >= 10 and index <=15'])
# Out:
#     carat|cut|color|clarity|depth|table|price|x|y|z
# 10      0.3|Good|J|SI1|64.0|55.0|339|4.25|4.28|2.73
# 11     0.23|Ideal|J|VS1|62.8|56.0|340|3.93|3.9|2.46
# 12  0.22|Premium|F|SI1|60.4|61.0|342|3.88|3.84|2.33
# 13    0.31|Ideal|J|SI2|62.2|54.0|344|4.35|4.37|2.71
# 14   0.2|Premium|E|SI2|60.2|62.0|345|3.79|3.75|2.27
# 15   0.32|Premium|E|I1|60.9|58.0|345|4.38|4.42|2.68

# %%
h5data.keys()
# Out:
# ['/obj1', '/obj2']

# %%
h5data.get_node("obj2")
# Out:
# /obj2 (Group) ''
#   children := ['table' (Table)]

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
titanic.dtypes[titanic.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic.dtypes[titanic.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df1 = titanic[titanic.dtypes[titanic.dtypes == 'object'].index]

# %%
df1
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df1.describe()
# Out:
#                               Name   Sex Ticket Cabin Embarked
# count                          891   891    891   204      889
# unique                         891     2    681   147        3
# top     Andreasson, Mr. Paul Edvin  male   1601    G6        S
# freq                             1   577      7     4      644

# %%
titanic['Age'].dtype
# Out:
# dtype('float64')

# %%
titanic['Name'][0:5] #same sclicing operation possible as list since this is of series data type
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
titanic['Name'][-1::-1]
# Out:
# 890                                  Dooley, Mr. Patrick
# 889                                Behr, Mr. Karl Howell
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 887                         Graham, Miss. Margaret Edith
# 886                                Montvila, Rev. Juozas
#                              ...
# 4                               Allen, Mr. William Henry
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2                                 Heikkinen, Miss. Laina
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 0                                Braund, Mr. Owen Harris
# Name: Name, Length: 891, dtype: object

# %%
sorted(titanic['Age'])[:10]
# Out:
# [2.0, 2.0, 3.0, 4.0, 7.0, 8.0, 14.0, 14.0, 14.0, 15.0]

# %%
# adding new column in data frame

titanic['newPassengerId'] = titanic['PassengerId']
titanic['boatName'] = "titanic"

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# To get distinct categories of data 

pd.Categorical(titanic['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(titanic['Embarked']).categories
# Out:
# Index(['C', 'Q', 'S'], dtype='object')

# %%
titanic['Cabin'].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
titanic['Embarked'].unique
# Out:
# <bound method Series.unique of 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object>

# %%
titanic[titanic['Cabin'].isnull() == False]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
indexes = titanic[titanic['Cabin'].isnull() == False].index

# %%
indexes
# Out:
# Int64Index([  1,   3,   6,  10,  11,  21,  23,  27,  31,  52,
#             ...
#             849, 853, 857, 862, 867, 871, 872, 879, 887, 889],
#            dtype='int64', length=204)

# %%
titanic.iloc[indexes]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic['Fare'] == titanic['Fare'].max()]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic['Name'][titanic['Fare'] == max( titanic['Fare'])] # Alternate way
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic.shape
# Out:
# (891, 14)

# %%
titanic.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# https://drive.google.com/file/d/1etGP85wJWsgqbsh3gX5oxc8dPKLMA1eT/view
#
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt
# https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv
# https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv
