# %% [markdown]
# # Ref- https://nbviewer.org/github/c17hawke/Exploring_deep_learning/blob/master/edge%20detection%20basics/demo_codes_for_edge_detection.ipynb

# %%
# !pip install opencv-python

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2

# %%
img_url ="img_resources/flower-puns.jpg"

# %%
# reading image with matplotlib
img = mpimg.imread(img_url)

# %%
# last index represents 3 channel for RGB colorspace
img.shape
# Out:
# (1280, 1920, 3)

# %%
# type remains an n dimensional numpy array
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
# reading with opencv
# use below code for colab only
# comment this whole cell if you are using this notebook in your PC
from google.colab.patches import cv2_imshow 

# get the image
image1 = cv2.imread('car1.jpeg')
cv2_imshow(image1)

# %%
# reading with opencv
# use below code for PC only

# get the image
image1 = cv2.imread(img_url)
cv2.imshow(winname="",mat=image1)
