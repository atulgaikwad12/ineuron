# %%
# !pip install mitoinstaller
# Out:
# ...
#   Created wheel for mitoinstaller: filename=mitoinstaller-0.0.61-py3-none-any.whl size=9110 sha256=89d6102b5e875954cddf1d3efe62050058c2be0a0d285bed3107a10e3c728199
#   Stored in directory: c:\users\atul gaikwad\appdata\local\pip\cache\wheels\b4\4e\c3\b98428b8240b11f2c73a0a5cca7b93f283ccf854360c11202a
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4835 sha256=c039ab04ca2bc10cc8b01b0d8fd2db7e18cca51a0a6ed613d82999544e60d251
#   Stored in directory: c:\users\atul gaikwad\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built mitoinstaller termcolor
# ...

# %%
# !python -m mitoinstaller install
# Out:
# Starting install...
# Upgrading mitoinstaller
# Checking dependencies
# Installing mitosheet3
# Traceback (most recent call last):
#   File "D:\Anaconda3\lib\site-packages\mitoinstaller\install.py", line 284, in do_install_or_upgrade
#     install_step['execute']()
#   File "D:\Anaconda3\lib\site-packages\mitoinstaller\install.py", line 135, in install_step_mitosheet3_install_mitosheet3
#     install_pip_packages('mitosheet3')
#   File "D:\Anaconda3\lib\site-packages\mitoinstaller\commands.py", line 95, in install_pip_packages
#     run_command(sys_call)
#   File "D:\Anaconda3\lib\site-packages\mitoinstaller\commands.py", line 40, in run_command
#     raise Exception(get_output(completed_process))
# Exception: Collecting mitosheet3
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11434 sha256=3158f37415b1c855762ed964b3d6fcdf983125dd0e34cefd2469c5d60059debe
# ...
