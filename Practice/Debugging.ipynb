# %%
import ipdb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5aecdc9391ac> in <module>
# ----> 1 import ipdb
#
# ModuleNotFoundError: No module named 'ipdb'

# %%
# !pip install ipdb
#if access defined issue ouccrs then use below command
# !pip install --user ipdb
# Out:
# ...
#   Created wheel for ipdb: filename=ipdb-0.13.7-py3-none-any.whl size=11438 sha256=59c8a52edb45500d081ee7b926d7f21cfac6ff3719852f7dbd8bb735238399c2
#   Stored in directory: c:\users\atul gaikwad\appdata\local\pip\cache\wheels\b3\e6\33\23ed5c0ce0654cd1426587c22918c3854c5e2583473e61538b
# Successfully built ipdb
# ...
#   Attempting uninstall: toml
#     Found existing installation: toml 0.10.1
#     Uninstalling toml-0.10.1:
#       Successfully uninstalled toml-0.10.1
# ...

# %%
import ipdb

# %%
def testdebug():
    ipdb.set_trace()
    l = []
    for i in range(10):
        l.append(i)
        print("we have appended your data in list ")
    return l

# %%
testdebug()
# Out:
# > <ipython-input-8-731cd2ddacfb>(3)testdebug()
#       2     ipdb.set_trace()
# ----> 3     l = []
#       4     for i in range(10):
#
# ipdb> h
#
# Documented commands (type help <topic>):
# ...
# EOF    cl         disable  interact  next    psource  rv           undisplay
# a      clear      display  j         p       q        s            unt
# alias  commands   down     jump      pdef    quit     skip_hidden  until
# args   condition  enable   l         pdoc    r        source       up
# b      cont       exit     list      pfile   restart  step         w
# break  continue   h        ll        pinfo   return   tbreak       whatis
# bt     d          help     longlist  pinfo2  retval   u            where
# c      debug      ignore   n         pp      run      unalias
#
# Miscellaneous help topics:
# ...
# exec  pdb
#
# ipdb> next
# > <ipython-input-8-731cd2ddacfb>(4)testdebug()
#       3     l = []
# ----> 4     for i in range(10):
#       5         l.append(i)
#
# ipdb> next
# ...
